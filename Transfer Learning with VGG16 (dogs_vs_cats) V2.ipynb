# %% [markdown]
# <a href="https://colab.research.google.com/github/aminmh/ml/blob/main/Transfer%20Learning%20with%20VGG16%20(dogs_vs_cats)%20V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir ~/.kaggle

# %%
# !mv kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  99% 805M/812M [00:00<00:00, 1.68GB/s]
# 100% 812M/812M [00:00<00:00, 1.68GB/s]

# %%
# !unzip dogs-vs-cats.zip
# Out:
# Archive:  dogs-vs-cats.zip
#   inflating: sampleSubmission.csv
#   inflating: test1.zip
#   inflating: train.zip

# %%
# !unzip -qq train.zip

# %%
# !ls train | wc -l
# Out:
# 25000

# %%
import os
import shutil
from glob import glob

# %%
# !rm -r dogs-vs-cats.zip sampleSubmission.csv test1.zip train.zip sample_data/

# %%
import tensorflow.keras as keras

# %%
from pathlib import Path

# %%
# The path to the directory where the original
# dataset was uncompressed
original_dataset_dir = '/content/train'
batch_size = 32
IMAGE_SIZE = (180, 180)

# %%
files_lengh = len(glob(original_dataset_dir+'/*.jpg'))

# %%
# Directory with our training cat pictures
train_cats_dir = os.path.join(original_dataset_dir, 'cats')
os.mkdir(train_cats_dir)

# Directory with our training dog pictures
train_dogs_dir = os.path.join(original_dataset_dir, 'dogs')
os.mkdir(train_dogs_dir)

# %%
# Copy first 1000 cat images to train_cats_dir
fnames = list(glob(original_dataset_dir + '/cat*.jpg'))
for fname in fnames:
    shutil.copyfile(fname, train_cats_dir + '/' + fname.split('/')[-1])

# %%
fnames = list(glob(original_dataset_dir + '/dog*.jpg'))
for fname in fnames:
    shutil.copyfile(fname, train_dogs_dir + '/' + fname.split('/')[-1])

# %%
for file in list(glob(original_dataset_dir + '/*.jpg')):
  os.remove(file)

# %%
print (f"cat images: {len(glob(train_cats_dir + '/cat*.jpg'))}")
print (f"dog images: {len(glob(train_dogs_dir + '/dog*.jpg'))}")
# Out:
# cat images: 12500
# dog images: 12500

# %%
train_dataset = keras.utils.image_dataset_from_directory(
    Path(original_dataset_dir),
    validation_split=0.2,
    seed=42,
    subset="training",
    image_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.

# %%
validation_dataset = keras.utils.image_dataset_from_directory(
    Path(original_dataset_dir),
    validation_split=0.2,
    seed=42,
    subset="validation",
    image_size=IMAGE_SIZE,
    batch_size=batch_size
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
import tensorflow as tf

# %%
validation_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(validation_batches // 5)
validation_dataset = validation_dataset.skip(validation_batches // 5)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = keras.Sequential([
    keras.layers.RandomFlip(),
    keras.layers.RandomRotation(0.2),
    keras.layers.RandomZoom(0.2),
])

# %%
rescale = keras.layers.Rescaling(1./255)

# %%
IMAGE_SHAPE = IMAGE_SIZE + (3,)
vgg_model = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=IMAGE_SHAPE,
)

# %%
global_avg_pooling = keras.layers.GlobalAveragePooling2D()

# %%
from keras.applications.vgg16 import preprocess_input

# %%
prediction_layer = keras.layers.Dense(1)
inputs = keras.Input(shape=IMAGE_SHAPE)

# %%
len(vgg_model.layers)
# Out:
# 19

# %%
vgg_model.trainable = True

# %%
# @title
for layer in vgg_model.layers[:15]:
  layer.trainable = False

# %%
x = data_augmentation(inputs)
x = preprocess_input(x)
x = vgg_model(x)
x = global_avg_pooling(x)
x = keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = keras.Model(inputs, outputs)

# %%
len(model.trainable_variables)
# Out:
# 8

# %%
model.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 180, 180,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential_2        │ (None, 180, 180,  │          0 │ input_layer_13[0… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_18         │ (None, 180, 180)  │          0 │ sequential_2[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_19         │ (None, 180, 180)  │          0 │ sequential_2[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_20         │ (None, 180, 180)  │          0 │ sequential_2[0][… │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stack_6 (Stack)     │ (None, 180, 180,  │          0 │ get_item_18[0][0… │
# │                     │ 3)                │            │ get_item_19[0][0… │
# │                     │                   │            │ get_item_20[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 180, 180,  │          0 │ stack_6[0][0]     │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vgg16 (Functional)  │ (None, 5, 5, 512) │ 14,714,688 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ vgg16[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │        513 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 14,715,201 (56.13 MB)
#  Trainable params: 7,079,937 (27.01 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %%
from keras import optimizers

model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy(threshold=0.0)]
)

# %%
history = model.fit(
      train_dataset,
      epochs=20,
      validation_data=validation_dataset
)
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - binary_accuracy: 0.8283 - loss: 0.4968 - val_binary_accuracy: 0.9681 - val_loss: 0.0995
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9316 - loss: 0.1732 - val_binary_accuracy: 0.9683 - val_loss: 0.0822
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - binary_accuracy: 0.9498 - loss: 0.1380 - val_binary_accuracy: 0.9760 - val_loss: 0.0592
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - binary_accuracy: 0.9564 - loss: 0.1151 - val_binary_accuracy: 0.9765 - val_loss: 0.0596
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9640 - loss: 0.0941 - val_binary_accuracy: 0.9760 - val_loss: 0.0622
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - binary_accuracy: 0.9613 - loss: 0.0990 - val_binary_accuracy: 0.9820 - val_loss: 0.0523
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9675 - loss: 0.0874 - val_binary_accuracy: 0.9803 - val_loss: 0.0544
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9675 - loss: 0.0813 - val_binary_accuracy: 0.9823 - val_loss: 0.0512
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9725 - loss: 0.0753 - val_binary_accuracy: 0.9763 - val_loss: 0.0562
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9721 - loss: 0.0748 - val_binary_accuracy: 0.9706 - val_loss: 0.0879
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9730 - loss: 0.0717 - val_binary_accuracy: 0.9758 - val_loss: 0.0691
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - binary_accuracy: 0.9765 - loss: 0.0598 - val_binary_accuracy: 0.9731 - val_loss: 0.0810
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9780 - loss: 0.0611 - val_binary_accuracy: 0.9793 - val_loss: 0.0624
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9766 - loss: 0.0625 - val_binary_accuracy: 0.9828 - val_loss: 0.0522
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9799 - loss: 0.0561 - val_binary_accuracy: 0.9778 - val_loss: 0.0623
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9785 - loss: 0.0568 - val_binary_accuracy: 0.9790 - val_loss: 0.0573
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9818 - loss: 0.0491 - val_binary_accuracy: 0.9795 - val_loss: 0.0628
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9823 - loss: 0.0468 - val_binary_accuracy: 0.9798 - val_loss: 0.0604
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9851 - loss: 0.0406 - val_binary_accuracy: 0.9800 - val_loss: 0.0579
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 20ms/step - binary_accuracy: 0.9828 - loss: 0.0476 - val_binary_accuracy: 0.9785 - val_loss: 0.0674

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
